# %% [markdown]
# # Minor Project

# %% [markdown]
# # Exploratory Data Analysis
#
# 1.Handle Missing Values
# 2.Removing Duplications
# 3.Normilizing And Sorting/scaling
# 4.Encoding Categorical Variables[Dummy Variables]
# 5.Univariate And Bivariate Analysis

# %% [markdown]
# # Importing libraries and loadings file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Loding Dataset
ipl = pd.read_csv('IPL.csv')

# %% [markdown]
# # Understanding data

# %%
print(ipl.shape)
# Out:
# (636, 18)

# %%
print(ipl.columns)
# Out:
# Index(['sno', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'Man_of_Match', 'venue', 'F_umpire', 'S_Umpire',
#        'Unnamed: 17'],
#       dtype='object')

# %%
ipl.isnull()
# Out:
#        sno  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
print(ipl.toss_winner.value_counts())
ipl
# Out:
# Series([], Name: toss_winner, dtype: int64)
# Empty DataFrame
# Columns: [sno, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, Man_of_Match, venue, F_umpire, S_Umpire, Unnamed: 17]
# Index: []

# %% [markdown]
# # 1 D Plotting

# %%
ipl =ipl.loc[ipl['toss_winner']=='MI']

# %%
ipl
# Out:
#      sno  season       city      date team1 team2 toss_winner toss_decision  \
# 15    16    2008    Kolkata  29/04/08   KKR    MI         KKR           bat
# 22    23    2008     Mumbai  4/5/2008    MI    DD          DD         field
# 26    27    2008     Mumbai  7/5/2008    RR    MI          MI         field
# 30    31    2008  Bangalore  28/05/08   RCB    MI          MI         field
# 36    37    2008     Mumbai  14/05/08   CSK    MI          MI         field
# ..   ...     ...        ...       ...   ...   ...         ...           ...
# 613  614    2017     Mumbai  1/5/2017   RCB    MI         RCB           bat
# 620  621    2017      Delhi  6/5/2017    MI    DD          DD         field
# 629  630    2017    Kolkata  13/05/17    MI   KKR         KKR         field
# 634  635    2017  Bangalore  19/05/17   KKR    MI          MI         field
# 635  636    2017  Hyderabad  21/05/17    MI   RPS          MI           bat
#
# ...

# %%
ipl =ipl.loc[ipl['toss_winner']=='DD']
ipl
# Out:
#      sno  season           city       date team1 team2 toss_winner  \
# 22    23    2008         Mumbai   4/5/2008    MI    DD          DD
# 123  124    2010          Delhi   17/03/10    MI    DD          DD
# 178  179    2011          Delhi  10/4/2011    DD    MI          DD
# 222  223    2011         Mumbai   7/5/2011    MI    DD          DD
# 448  449    2014         Mumbai   23/05/14    MI    DD          DD
# 496  497    2015         Mumbai   5/5/2015    DD    MI          DD
# 563  564    2016  Visakhapatnam   15/05/16    MI    DD          DD
# 600  601    2017         Mumbai   22/04/17    MI    DD          DD
# 620  621    2017          Delhi   6/5/2017    MI    DD          DD
#
#     toss_decision  result dl_applied winner  win_by_runs  win_by_wickets  \
# 22          field  normal          N     MI           29               0
# 123         field  normal          N     MI           98               0
# 178           bat  normal          N     MI            0               8
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [sno, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, Man_of_Match, venue, F_umpire, S_Umpire, Unnamed: 17]
# Index: []

# %%
dd
# Out:
# Empty DataFrame
# Columns: [sno, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, Man_of_Match, venue, F_umpire, S_Umpire, Unnamed: 17]
# Index: []

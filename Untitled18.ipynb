# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'Apples':[30],'Bananas':[21],'Prices':[120]})
df
# Out:
#    AppleS  Bananas  Prices
# 0      30       21     120

# %%
df = pd.DataFrame({'Apples':[32],'Bananas':[56]},index = ['2017Sales','2018Sales'])
df
# Out:
#            Apples  Bananas
# 2017Sales      32       56
# 2018Sales      32       56

# %%
import pandas as pd 
import numpy as np
df = pd.series([4,5,6,4], index =['f','m','e','j'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-18cc191fbb8e> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.series([4,5,6,4], index =['f','m','e','j'])
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('IndividualDetails.csv')
df
# Out:
#           id government_id diagnosed_date  age gender  \
# 0          0      KL-TS-P1     30/01/2020   20      F
# 1          1      KL-AL-P1     02/02/2020  NaN    NaN
# 2          2      KL-KS-P1     03/02/2020  NaN    NaN
# 3          3         DL-P1     02/03/2020   45      M
# 4          4         TS-P1     02/03/2020   24      M
# ...      ...           ...            ...  ...    ...
# 18027  18029      TN-P1518     20/04/2020  NaN    NaN
# 18028  18030      TN-P1519     20/04/2020  NaN    NaN
# 18029  18031      TN-P1520     20/04/2020  NaN    NaN
# 18030  18032           NaN     20/04/2020  NaN    NaN
# 18031  18033           NaN     20/04/2020  NaN    NaN
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
df.sample()
# Out:
#           id government_id diagnosed_date  age gender detected_city  \
# 16965  16967           NaN     19/04/2020  NaN    NaN           NaN
#
#       detected_district detected_state nationality status_change_date  \
# 16965              Agra  Uttar Pradesh         NaN         19/04/2020
#
#                  notes
# 16965  Details awaited

# %%
df.sample()
# Out:
#         id government_id diagnosed_date  age gender detected_city  \
# 9993  9995           NaN     13/04/2020  NaN    NaN           NaN
#
#      detected_district detected_state nationality status_change_date  \
# 9993            Mumbai    Maharashtra         NaN         13/04/2020
#
#                 notes
# 9993  Details awaited

# %%
df.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality status_change_date  \
# 0          Thrissur         Kerala       India         14/02/2020
# 1         Alappuzha         Kerala       India         14/02/2020
# 2         Kasaragod         Kerala       India         14/02/2020
# 3        East Delhi          Delhi       India         15/03/2020
# 4         Hyderabad      Telangana       India         02/03/2020
#
#                                                notes
# 0                               Travelled from Wuhan
# ...

# %%
df.tail()
# Out:
#           id government_id diagnosed_date  age gender detected_city  \
# 18027  18029      TN-P1518     20/04/2020  NaN    NaN           NaN
# 18028  18030      TN-P1519     20/04/2020  NaN    NaN           NaN
# 18029  18031      TN-P1520     20/04/2020  NaN    NaN           NaN
# 18030  18032           NaN     20/04/2020  NaN    NaN           NaN
# 18031  18033           NaN     20/04/2020  NaN    NaN           NaN
#
#       detected_district detected_state nationality status_change_date  \
# 18027               NaN     Tamil Nadu         NaN         20/04/2020
# 18028               NaN     Tamil Nadu         NaN         20/04/2020
# 18029               NaN     Tamil Nadu         NaN         20/04/2020
# 18030            Bokaro      Jharkhand         NaN         20/04/2020
# 18031         Jalandhar         Punjab         NaN         20/04/2020
#
#                      notes
# 18027      Details awaited
# 18028      Details awaited
# 18029      Details awaited
# ...

# %%
df[df['government_id']=='TN-P1518']
# Out:
#           id government_id diagnosed_date  age gender detected_city  \
# 18027  18029      TN-P1518     20/04/2020  NaN    NaN           NaN
#
#       detected_district detected_state nationality status_change_date  \
# 18027               NaN     Tamil Nadu         NaN         20/04/2020
#
#                  notes
# 18027  Details awaited

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 3 * np.pi ,0.1)
y = np.sin(x)
plt.title("sin wave form")
plt.plot(x,y,"+")
plt.xlabel('axis x')
plt.ylabel('axis y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [10 , 20 , 30,25,35]
y = [25 , 63 ,89,90,100]
plt.bar(x,y,color = 'g')
plt.title("Bar Graph")
# Out:
# Text(0.5, 1.0, 'Bar Graph')
